# %% [markdown]
# # Create a Dictionary

# %%
students1 = {"name" : "ali","age":12,"City":"Multan","Class":6}
students1["City"]
for key in students1:
     print(students1[key])
for kv in students1.items():
    print(kv)
# Out:
# ali
# 12
# Multan
# 6
# ('name', 'ali')
# ('age', 12)
# ('City', 'Multan')
# ('Class', 6)

# %% [markdown]
# # Add Items to a Dictionary

# %%
country_capitals = {
  "Germany": "Berlin", 
  "Canada": "Ottawa", 
}

country_capitals["Italy"] = "Rome"

print(country_capitals)
# Out:
# {'Germany': 'Berlin', 'Canada': 'Ottawa', 'Italy': 'Rome'}

# %% [markdown]
# # Remove Dictionary Items

# %%
country_capitals = {
  "Germany": "Berlin", 
  "Canada": "Ottawa", 
}

del country_capitals["Germany"]

print(country_capitals)
# Out:
# {'Canada': 'Ottawa'}

# %% [markdown]
# # All the clear

# %%
country_capitals = {
  "Germany": "Berlin", 
  "Canada": "Ottawa", 
}

country_capitals.clear()

print(country_capitals)
# Out:
# {}

# %% [markdown]
# # Change Dictionary Items

# %%
country_capitals = {
  "Germany": "Berlin", 
  "Italy": "Naples", 
  "England": "London"
}
country_capitals["Italy"] = "Rome"

print(country_capitals)
# Out:
# {'Germany': 'Berlin', 'Italy': 'Rome', 'England': 'London'}

# %% [markdown]
# # Iterate Through a Dictionary

# %%
country_capitals = {
  "United States": "Washington D.C.", 
  "Italy": "Rome" 
}

# print dictionary keys one by one
for country in country_capitals:
    print(country)

print()

# print dictionary values one by one
for country in country_capitals:
    capital = country_capitals[country]
    print(capital)
# Out:
# United States
# Italy
#
# Washington D.C.
# Rome

# %% [markdown]
# # Find Dictionary Length

# %%
country_capitals = {"England": "London", "Italy": "Rome"}

# get dictionary's length
print(len(country_capitals))   # Output: 2

numbers = {10: "ten", 20: "twenty", 30: "thirty"}

# get dictionary's length
print(len(numbers))            # Output: 3

countries = {}

# get dictionary's length
print(len(countries))          # Output: 0
# Out:
# 2
# 3
# 0

# %% [markdown]
# # Task assign

# %%
dict = {
    'name' : 'Ali',
    'age' : 18,
    'city' : 'Multan',
    'institute' : 'corvit'
}
for info in dict:
    print(info)
# add key and find a value

dict['institute']
# Out:
# name
# age
# city
# institute
# 'corvit'

# %% [markdown]
# # remove

# %%
dict = {
    'name' : 'Ali',
    'age' : 18,
    'city' : 'Multan',
    'institute' : 'corvit'
}
del dict['age']
print(dict)
# Out:
# {'name': 'Ali', 'city': 'Multan', 'institute': 'corvit'}

# %% [markdown]
# # print all keys value pair

# %%
dict = {
    'name' : 'Ali',
    'age' : 18,
    'city' : 'Multan',
    'institute' : 'corvit'
}
for kv in dict.items():
    print(kv)
# Out:
# ('name', 'Ali')
# ('age', 18)
# ('city', 'Multan')
# ('institute', 'corvit')

# %% [markdown]
# # if check dict[city]

# %%
dict = {
    'name' : 'Ali',
    'age' : 18,
    'city' : 'Multan',
    'institute' : 'corvit'
}
if 'city' in dict:
    print("City exist krta ha ")
else:
    print("City exist nahi krta ha")
# Out:
# City exist krta ha

# %% [markdown]
# # Merge both dictionary

# %%
numbers = {
    'ten' : 10,
    'twenty' : 20,
    'thirty' : 30 
}
num = {
    'fourty' : 40,
    'fifty' : 50,
    'sixty' : 60
}
print(numbers | num)
# Out:
# {'ten': 10, 'twenty': 20, 'thirty': 30, 'fourty': 40, 'fifty': 50, 'sixty': 60}

# %% [markdown]
# # Create dictionary and print their frequencies

# %%
string = 'NAVTTC'

str = {}
for item in string:
    if item in str:
        str[item] += 1
    else:
        str[item] = 1
print(str)
# Out:
# {'N': 1, 'A': 1, 'V': 1, 'T': 2, 'C': 1}
